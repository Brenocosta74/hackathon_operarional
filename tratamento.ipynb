# %%
import pandas as pd

df = pd.read_excel("Materiais.xlsx")

display(df)
# Out:
#     Id_material         Nome  Quantidade_uso  Unidade Setor_uso  \
# 0             1        fugit           44.59       kg   Higiene
# 1             2         esse            8.19       kg  Produção
# 2             3         quod            4.86  unidade   Higiene
# 3             4    inventore           45.94  unidade  Produção
# 4             5          sit           45.55    litro   Higiene
# ..          ...          ...             ...      ...       ...
# 95           96       libero           19.95    litro  Produção
# 96           97  perferendis           47.81  unidade   Cozinha
# 97           98      commodi           44.19       kg   Cozinha
# 98           99      nostrum           15.59       kg   Higiene
# 99          100           in            2.07  unidade   Higiene
#
#     Custo_unitario                  Fornecedor                  Filial  Turno
# 0           190.84                        Rios  Casa Grande das Pedras  Manhã
# ...

# %%
df = df.drop(columns="Nome")
display(df)
# Out:
#     Id_material  Quantidade_uso  Unidade Setor_uso  Custo_unitario  \
# 0             1           44.59       kg   Higiene          190.84
# 1             2            8.19       kg  Produção           14.00
# 2             3            4.86  unidade   Higiene           94.99
# 3             4           45.94  unidade  Produção           98.76
# 4             5           45.55    litro   Higiene           -5.00
# ..          ...             ...      ...       ...             ...
# 95           96           19.95    litro  Produção          157.56
# 96           97           47.81  unidade   Cozinha           51.90
# 97           98           44.19       kg   Cozinha          173.94
# 98           99           15.59       kg   Higiene           18.63
# 99          100            2.07  unidade   Higiene          177.74
#
#                     Fornecedor                  Filial  Turno
# 0                         Rios  Casa Grande das Pedras  Manhã
# ...

# %%
df['Quantidade_uso'].fillna('Desconhecido', inplace=True)
display(df)
# Out:
# C:\Users\46859443804\AppData\Local\Temp\ipykernel_29140\585092385.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Quantidade_uso'].fillna('Desconhecido', inplace=True)
#     Id_material  Quantidade_uso  Unidade Setor_uso  Custo_unitario  \
# 0             1           44.59       kg   Higiene          190.84
# 1             2            8.19       kg  Produção           14.00
# 2             3            4.86  unidade   Higiene           94.99
# ...

# %%
df['Setor_uso'].fillna('Desconhecido', inplace=True)
display(df)
# Out:
# C:\Users\46859443804\AppData\Local\Temp\ipykernel_29140\335886105.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Setor_uso'].fillna('Desconhecido', inplace=True)
#     Id_material  Quantidade_uso  Unidade Setor_uso  Custo_unitario  \
# 0             1           44.59       kg   Higiene          190.84
# 1             2            8.19       kg  Produção           14.00
# 2             3            4.86  unidade   Higiene           94.99
# 3             4           45.94  unidade  Produção           98.76
# ...

# %%
df['Custo_unitario'].fillna('Desconhecido', inplace=True)
display(df)
# Out:
# C:\Users\46859443804\AppData\Local\Temp\ipykernel_29140\2117855429.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Custo_unitario'].fillna('Desconhecido', inplace=True)
#     Id_material  Quantidade_uso  Unidade Setor_uso  Custo_unitario  \
# 0             1           44.59       kg   Higiene          190.84
# 1             2            8.19       kg  Produção           14.00
# 2             3            4.86  unidade   Higiene           94.99
# ...

# %%
df['Fornecedor'].fillna('Desconhecido', inplace=True)
display(df)
# Out:
# C:\Users\46859443804\AppData\Local\Temp\ipykernel_29140\899019672.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fornecedor'].fillna('Desconhecido', inplace=True)
#     Id_material  Quantidade_uso  Unidade Setor_uso  Custo_unitario  \
# 0             1           44.59       kg   Higiene          190.84
# 1             2            8.19       kg  Produção           14.00
# 2             3            4.86  unidade   Higiene           94.99
# 3             4           45.94  unidade  Produção           98.76
# ...

# %%
df['Filial'].fillna('Desconhecido', inplace=True)
display(df)
# Out:
# C:\Users\46859443804\AppData\Local\Temp\ipykernel_29140\1720589217.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Filial'].fillna('Desconhecido', inplace=True)
#     Id_material  Quantidade_uso  Unidade Setor_uso  Custo_unitario  \
# 0             1           44.59       kg   Higiene          190.84
# 1             2            8.19       kg  Produção           14.00
# 2             3            4.86  unidade   Higiene           94.99
# 3             4           45.94  unidade  Produção           98.76
# ...

# %%
df['Turno'].fillna('Desconhecido', inplace=True)
display(df)
# Out:
# C:\Users\46859443804\AppData\Local\Temp\ipykernel_29140\2867831662.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Turno'].fillna('Desconhecido', inplace=True)
#     Id_material  Quantidade_uso  Unidade Setor_uso  Custo_unitario  \
# 0             1           44.59       kg   Higiene          190.84
# 1             2            8.19       kg  Produção           14.00
# 2             3            4.86  unidade   Higiene           94.99
# 3             4           45.94  unidade  Produção           98.76
# ...

# %%
df.to_excel("tratamento.xlsx")

# %%
df = pd.read_excel("tratamento.xlsx")
display(df)
# Out:
#     Unnamed: 0  Id_material  Quantidade_uso  Unidade Setor_uso  \
# 0            0            1           44.59       kg   Higiene
# 1            1            2            8.19       kg  Produção
# 2            2            3            4.86  unidade   Higiene
# 3            3            4           45.94  unidade  Produção
# 4            4            5           45.55    litro   Higiene
# ..         ...          ...             ...      ...       ...
# 95          95           96           19.95    litro  Produção
# 96          96           97           47.81  unidade   Cozinha
# 97          97           98           44.19       kg   Cozinha
# 98          98           99           15.59       kg   Higiene
# 99          99          100            2.07  unidade   Higiene
#
#     Custo_unitario                  Fornecedor                  Filial  Turno
# 0           190.84                        Rios  Casa Grande das Pedras  Manhã
# ...
